# %% [markdown]
# # 1. Importing packages

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import random
import os

from tensorflow.keras.layers import Input , Dense , Flatten , GlobalAveragePooling2D
from tensorflow.keras.models import Sequential

# %%
path = '../input/4-animal-classification'

# %% [markdown]
# # 2. Visualising data

# %%
names = []
nums = []
data = {'Name of class':[],'Number of samples':[]}

for i in os.listdir(path+'/train'):
    nums.append(len(os.listdir(path+'/train/'+i)))
    names.append(i)

data['Name of class']+=names
data['Number of samples']+=nums

df = pd.DataFrame(data)
df
# Out:
#   Name of class  Number of samples
# 0         horse                600
# 1           dog                900
# 2           cat                700
# 3          deer                600

# %%
sns.barplot(x=df['Name of class'],y=df['Number of samples'])
# Out:
# <AxesSubplot:xlabel='Name of class', ylabel='Number of samples'>

# %%
classes = os.listdir(path+'/train')

plt.figure(figsize=(30 , 30))
for x in range(10):
    i = random.randint(0,3)                    # getting the class
    images = os.listdir(path+'/train'+'/'+classes[i])
    j = random.randint(0,600)                  # getting the image
    image = cv2.imread(path+'/train'+'/'+classes[i]+'/'+images[j])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    ax = plt.subplot(5, 5, x + 1)
    plt.imshow(image)
    plt.title(classes[i])
    plt.axis("off")

plt.show()

# %% [markdown]
# # 3. Preparing the data

# %%
image_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255 , rotation_range=20,
                                                                width_shift_range=0.2,
                                                                height_shift_range=0.2,
                                                                horizontal_flip=True, validation_split=0.2)

# %%
train_ds = image_datagen.flow_from_directory(
        path+'/train',
        subset='training',
        target_size=(224 , 224),
        batch_size=32)

val_ds = image_datagen.flow_from_directory(
        path+'/train',
        subset='validation',
        target_size=(224 , 224),
        batch_size=32 )
# Out:
# Found 2240 images belonging to 4 classes.
# Found 560 images belonging to 4 classes.

# %% [markdown]
# # 4. Building the model

# %%
# i'll be using inception_v3 for this model , along with 2 extra dense layers and the output layer

mobilenet = tf.keras.applications.mobilenet.MobileNet(input_shape=(224 , 224, 3),
                                           include_top=False,
                                           weights='imagenet')

model = Sequential()
model.add(mobilenet)
model.add(GlobalAveragePooling2D())
model.add(Flatten())
model.add(Dense(1024, activation="relu"))
model.add(Dense(512, activation="relu"))
model.add(Dense(256, activation="relu"))
model.add(Dense(4, activation="softmax" , name="classification"))
# Out:
# 2022-09-24 10:35:46.737954: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-24 10:35:46.873042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-24 10:35:46.877076: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-24 10:35:46.881614: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-24 10:35:46.882141: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-24 10:35:46.885794: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-24 10:35:46.890195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-24 10:35:49.726364: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-24 10:35:49.730446: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-24 10:35:49.734527: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-24 10:35:49.738227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0005,momentum=0.9), 
            loss='categorical_crossentropy',
            metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# classification (Dense)       (None, 4)                 1028
# =================================================================
# Total params: 4,935,620
# Trainable params: 4,913,732
# Non-trainable params: 21,888
# _________________________________________________________________

# %% [markdown]
# # 5. Training and evaluating

# %%
history = model.fit(train_ds , validation_data = val_ds , epochs = 50)
# Out:
# 2022-09-24 10:35:52.859778: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-09-24 10:35:57.806130: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 70/70 [==============================] - 81s 1s/step - loss: 0.8909 - accuracy: 0.6875 - val_loss: 0.4971 - val_accuracy: 0.8661
# Epoch 2/50
# 70/70 [==============================] - 55s 784ms/step - loss: 0.3428 - accuracy: 0.9112 - val_loss: 0.2806 - val_accuracy: 0.9161
# Epoch 3/50
# 70/70 [==============================] - 55s 783ms/step - loss: 0.2240 - accuracy: 0.9295 - val_loss: 0.2117 - val_accuracy: 0.9393
# Epoch 4/50
# 70/70 [==============================] - 54s 776ms/step - loss: 0.1771 - accuracy: 0.9478 - val_loss: 0.1956 - val_accuracy: 0.9393
# Epoch 5/50
# 70/70 [==============================] - 54s 777ms/step - loss: 0.1420 - accuracy: 0.9554 - val_loss: 0.1643 - val_accuracy: 0.9500
# Epoch 6/50
# 70/70 [==============================] - 55s 790ms/step - loss: 0.1154 - accuracy: 0.9670 - val_loss: 0.1493 - val_accuracy: 0.9464
# Epoch 7/50
# 70/70 [==============================] - 55s 785ms/step - loss: 0.1024 - accuracy: 0.9661 - val_loss: 0.1519 - val_accuracy: 0.9536
# Epoch 8/50
# 70/70 [==============================] - 54s 769ms/step - loss: 0.0861 - accuracy: 0.9714 - val_loss: 0.1526 - val_accuracy: 0.9518
# Epoch 9/50
# 70/70 [==============================] - 54s 777ms/step - loss: 0.0901 - accuracy: 0.9688 - val_loss: 0.1576 - val_accuracy: 0.9411
# Epoch 10/50
# 70/70 [==============================] - 54s 778ms/step - loss: 0.0741 - accuracy: 0.9777 - val_loss: 0.1357 - val_accuracy: 0.9589
# Epoch 11/50
# 70/70 [==============================] - 53s 762ms/step - loss: 0.0685 - accuracy: 0.9808 - val_loss: 0.1389 - val_accuracy: 0.9464
# Epoch 12/50
# 70/70 [==============================] - 54s 778ms/step - loss: 0.0541 - accuracy: 0.9817 - val_loss: 0.1202 - val_accuracy: 0.9625
# Epoch 13/50
# 70/70 [==============================] - 55s 784ms/step - loss: 0.0547 - accuracy: 0.9844 - val_loss: 0.1295 - val_accuracy: 0.9571
# Epoch 14/50
# 70/70 [==============================] - 57s 814ms/step - loss: 0.0378 - accuracy: 0.9920 - val_loss: 0.1383 - val_accuracy: 0.9518
# Epoch 15/50
# 70/70 [==============================] - 55s 794ms/step - loss: 0.0438 - accuracy: 0.9888 - val_loss: 0.1446 - val_accuracy: 0.9518
# Epoch 16/50
# 70/70 [==============================] - 55s 781ms/step - loss: 0.0432 - accuracy: 0.9884 - val_loss: 0.1488 - val_accuracy: 0.9500
# Epoch 17/50
# 70/70 [==============================] - 54s 778ms/step - loss: 0.0433 - accuracy: 0.9871 - val_loss: 0.1314 - val_accuracy: 0.9589
# Epoch 18/50
# 70/70 [==============================] - 54s 768ms/step - loss: 0.0458 - accuracy: 0.9839 - val_loss: 0.1248 - val_accuracy: 0.9625
# Epoch 19/50
# 70/70 [==============================] - 54s 773ms/step - loss: 0.0299 - accuracy: 0.9924 - val_loss: 0.1264 - val_accuracy: 0.9554
# Epoch 20/50
# 70/70 [==============================] - 54s 779ms/step - loss: 0.0262 - accuracy: 0.9937 - val_loss: 0.1338 - val_accuracy: 0.9536
# Epoch 21/50
# 70/70 [==============================] - 54s 778ms/step - loss: 0.0285 - accuracy: 0.9933 - val_loss: 0.1298 - val_accuracy: 0.9571
# Epoch 22/50
# 70/70 [==============================] - 56s 798ms/step - loss: 0.0325 - accuracy: 0.9915 - val_loss: 0.1572 - val_accuracy: 0.9482
# Epoch 23/50
# 70/70 [==============================] - 57s 822ms/step - loss: 0.0265 - accuracy: 0.9942 - val_loss: 0.1260 - val_accuracy: 0.9536
# Epoch 24/50
# 70/70 [==============================] - 57s 808ms/step - loss: 0.0233 - accuracy: 0.9946 - val_loss: 0.1463 - val_accuracy: 0.9643
# Epoch 25/50
# 70/70 [==============================] - 56s 797ms/step - loss: 0.0322 - accuracy: 0.9906 - val_loss: 0.1216 - val_accuracy: 0.9607
# Epoch 26/50
# 70/70 [==============================] - 56s 798ms/step - loss: 0.0171 - accuracy: 0.9960 - val_loss: 0.1563 - val_accuracy: 0.9500
# Epoch 27/50
# 70/70 [==============================] - 56s 808ms/step - loss: 0.0216 - accuracy: 0.9951 - val_loss: 0.1446 - val_accuracy: 0.9589
# Epoch 28/50
# 70/70 [==============================] - 56s 800ms/step - loss: 0.0172 - accuracy: 0.9964 - val_loss: 0.1282 - val_accuracy: 0.9625
# Epoch 29/50
# 70/70 [==============================] - 53s 760ms/step - loss: 0.0189 - accuracy: 0.9929 - val_loss: 0.1515 - val_accuracy: 0.9589
# Epoch 30/50
# 70/70 [==============================] - 54s 778ms/step - loss: 0.0199 - accuracy: 0.9942 - val_loss: 0.1489 - val_accuracy: 0.9536
# Epoch 31/50
# 70/70 [==============================] - 54s 780ms/step - loss: 0.0150 - accuracy: 0.9978 - val_loss: 0.1260 - val_accuracy: 0.9589
# Epoch 32/50
# 70/70 [==============================] - 54s 774ms/step - loss: 0.0251 - accuracy: 0.9937 - val_loss: 0.1221 - val_accuracy: 0.9625
# Epoch 33/50
# 70/70 [==============================] - 55s 777ms/step - loss: 0.0098 - accuracy: 0.9982 - val_loss: 0.1423 - val_accuracy: 0.9571
# Epoch 34/50
# 70/70 [==============================] - 54s 779ms/step - loss: 0.0160 - accuracy: 0.9960 - val_loss: 0.1668 - val_accuracy: 0.9571
# Epoch 35/50
# 70/70 [==============================] - 54s 770ms/step - loss: 0.0172 - accuracy: 0.9951 - val_loss: 0.1685 - val_accuracy: 0.9500
# Epoch 36/50
# 70/70 [==============================] - 55s 775ms/step - loss: 0.0134 - accuracy: 0.9969 - val_loss: 0.1708 - val_accuracy: 0.9518
# Epoch 37/50
# 70/70 [==============================] - 54s 775ms/step - loss: 0.0163 - accuracy: 0.9955 - val_loss: 0.1732 - val_accuracy: 0.9589
# Epoch 38/50
# 70/70 [==============================] - 54s 775ms/step - loss: 0.0191 - accuracy: 0.9937 - val_loss: 0.1476 - val_accuracy: 0.9554
# Epoch 39/50
# 70/70 [==============================] - 54s 771ms/step - loss: 0.0202 - accuracy: 0.9946 - val_loss: 0.1411 - val_accuracy: 0.9607
# Epoch 40/50
# 70/70 [==============================] - 55s 792ms/step - loss: 0.0116 - accuracy: 0.9955 - val_loss: 0.1702 - val_accuracy: 0.9607
# Epoch 41/50
# 70/70 [==============================] - 54s 778ms/step - loss: 0.0159 - accuracy: 0.9946 - val_loss: 0.1445 - val_accuracy: 0.9429
# Epoch 42/50
# 70/70 [==============================] - 54s 773ms/step - loss: 0.0118 - accuracy: 0.9969 - val_loss: 0.1571 - val_accuracy: 0.9518
# Epoch 43/50
# 70/70 [==============================] - 54s 779ms/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 0.1601 - val_accuracy: 0.9536
# Epoch 44/50
# 70/70 [==============================] - 54s 776ms/step - loss: 0.0136 - accuracy: 0.9964 - val_loss: 0.1653 - val_accuracy: 0.9536
# Epoch 45/50
# 70/70 [==============================] - 54s 771ms/step - loss: 0.0166 - accuracy: 0.9951 - val_loss: 0.1275 - val_accuracy: 0.9607
# Epoch 46/50
# 70/70 [==============================] - 54s 766ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.1462 - val_accuracy: 0.9554
# Epoch 47/50
# 70/70 [==============================] - 54s 773ms/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 0.1340 - val_accuracy: 0.9571
# Epoch 48/50
# 70/70 [==============================] - 55s 777ms/step - loss: 0.0095 - accuracy: 0.9982 - val_loss: 0.1382 - val_accuracy: 0.9589
# Epoch 49/50
# 70/70 [==============================] - 54s 775ms/step - loss: 0.0094 - accuracy: 0.9982 - val_loss: 0.1784 - val_accuracy: 0.9554
# Epoch 50/50
# 70/70 [==============================] - 54s 772ms/step - loss: 0.0068 - accuracy: 0.9987 - val_loss: 0.1476 - val_accuracy: 0.9607

# %%
model.evaluate(val_ds)

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'],loc='upper right')
plt.show()
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy','val_accuracy'],loc='upper right')
plt.show()
# Out:
# 18/18 [==============================] - 10s 554ms/step - loss: 0.1526 - accuracy: 0.9571

# %% [markdown]
# # 6. Preparing for submission

# %%
sub_csv ='../input/4-animal-classification/Sample_submission.csv'
path_test = '../input/4-animal-classification/test/test'

# %%
df_sub = pd.read_csv(sub_csv)
image_id = df_sub['ID']
df_sub.head(10)
# Out:
#    ID  Label
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
# 5   6      0
# 6   7      0
# 7   8      0
# 8   9      0
# 9  10      0

# %%
# each image will be treated individually and saved in a list which is then merged with the id of it's correspondence

from tensorflow.keras.preprocessing.image import load_img


# making a list for our predictions
labels = []


for i in image_id:
    image = load_img(path_test+'/'+str(i)+'.jpg', target_size=(224, 224))
    img = np.array(image)
    img = img / 255.0
    img = img.reshape(1,224,224,3)
    label = model.predict(img)
    label_id = label[0].tolist()
    
    labels.append(label_id.index(max(label_id)))

# %%
# we will replace the previous empty columns with the new predictions    
    
df_sub['Label'] = labels
df_sub.head(10)
# Out:
#    ID  Label
# 0   1      1
# 1   2      0
# 2   3      2
# 3   4      3
# 4   5      2
# 5   6      1
# 6   7      3
# 7   8      0
# 8   9      3
# 9  10      2

# %%
# saving file
df_sub.to_csv('submission_file.csv',index=False)
